# %%
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
# %matplotlib inline

# %%
n = 100
X = np.random.uniform(0, 10, n)
e = np.random.normal(0, 1, n)
Y = 2 + 3*X + e

# %%
n = 100
X = np.random.uniform(0, 10, n)
e = np.random.normal(0, 1, n)
Y = 2 + 3*X + X*e

# %%
fig, axs = plt.subplots(2,2, figsize = (15, 10))
ax = axs[0][0]
ax.scatter(X, Y, alpha = .5, s= 200)
